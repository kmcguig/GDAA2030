# %% [markdown]
# <a href="https://colab.research.google.com/github/kmcguig/GDAA2030/blob/master/folder/yeah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib notebook 
# %matplotlib inline 
from matplotlib import pyplot as plt 
import numpy as np

#![picture](https://github.com/kevinkmcguigan/GDAA2030/blob/master/tutorial1/tutorial1Image.PNG)

import requests
import matplotlib.image as mpimg

if 1:
  # url = 'https://github.com/kevinkmcguigan/GDAA2030/blob/master/tutorial1/tutorial1Image.PNG?raw=true'
  url = 'https://raw.githubusercontent.com/NSCC-COGS/GDAA2030/master/tutorial1/kevinkmcguigan/tutorial1Image.PNG'

  img_raw = requests.get(url, stream=True).raw
  img = mpimg.imread(img_raw)[:,:,:]
  plt.imshow(img)
  plt.show()




#![picture](https://github.com/kevinkmcguigan/GDAA2030/blob/master/tutorial1/tutorial1Image.PNG?raw=true)

# plt.ion()

if 0:
  for i in range(0,10):
    # print(i)
    a = np.random.rand(50,50)
    plt.subplot(1,1,1)
    plt.imshow(a)
    plt.pause(.0001)
    # plt.show()
    # plt.draw()

if 0:
  from IPython.display import clear_output
  import matplotlib.pyplot as plt
  from numpy.random import randn
  from time import sleep

  for i in range(10):
    # clear_output()
    plt.imshow(randn(28, 28))
    plt.show()
    # sleep(.5)
    plt.pause(1)
    clear_output()
    # plt.clf()
